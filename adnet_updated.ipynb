# %% [markdown]
# <a href="https://colab.research.google.com/github/saimayasmeen4/ADNET/blob/main/adnet_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ADNet/gray/
# Out:
# /content/drive/.shortcut-targets-by-id/1Wm1C7u1d8SQZbcql8lkPzumlg3EbyeNO/ADNet/gray

# %%
# import glob
# import os
# import os.path

# files1 = glob.glob(os.path.join('/content/drive/MyDrive/SAR/virtual_sar_training_set/clean_1c', '*'))
# #files = glob.glob(os.path.join(data_path, 'noisy_1c', '*.jpg'))
# print(len(files1[0:1500]))
# files2 = glob.glob(os.path.join('/content/drive/MyDrive/SAR/virtual_sar_training_set//noisy_1c', '*'))
# print(len(files2[0:1500]))
# files=files1[0:1500]+files2[0:1500]
# print(len(files))

# %%
# !python train.py --preprocess True --num_of_layers 17 --mode B
# Out:
# Streaming output truncated to the last 5000 lines.
# [epoch 1][3640/33844] loss: 0.7928 PSNR_train: 34.3764
# [epoch 1][3641/33844] loss: 0.8623 PSNR_train: 34.8434
# [epoch 1][3642/33844] loss: 0.9350 PSNR_train: 33.6963
# [epoch 1][3643/33844] loss: 0.7142 PSNR_train: 34.3043
# [epoch 1][3644/33844] loss: 0.9090 PSNR_train: 33.2100
# [epoch 1][3645/33844] loss: 0.9991 PSNR_train: 31.8543
# [epoch 1][3646/33844] loss: 0.9004 PSNR_train: 32.4438
# [epoch 1][3647/33844] loss: 1.0486 PSNR_train: 31.5998
# [epoch 1][3648/33844] loss: 0.9916 PSNR_train: 31.9388
# [epoch 1][3649/33844] loss: 1.0274 PSNR_train: 31.8682
# [epoch 1][3650/33844] loss: 0.9034 PSNR_train: 32.4702
# [epoch 1][3651/33844] loss: 0.8722 PSNR_train: 33.2639
# [epoch 1][3652/33844] loss: 0.9493 PSNR_train: 33.7225
# [epoch 1][3653/33844] loss: 1.1329 PSNR_train: 33.8070
# [epoch 1][3654/33844] loss: 1.2793 PSNR_train: 32.1571
# [epoch 1][3655/33844] loss: 0.9692 PSNR_train: 33.2661
# ...

# %%
# !python test_Gb.py --num_of_layers 17 --logdir gblind --test_data noisy_1c --test_noiseL 25
